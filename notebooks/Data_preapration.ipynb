# %%
import sqlite3
import pandas as pd
con=sqlite3.connect(r'C:\Users\msham\OneDrive\Documents\OJT\Proj3.1\data\raw\2_IPL_Cricket\ipl.db')


def q(sql):
     return pd.read_sql(sql, con)

# %%
q("""SELECT * FROM matches""")
# Out:
#       match_id  season_id  balls_per_over            city  match_date  \
# 0       335982       2008               6       Bangalore  2008-04-18
# 1      1082591       2017               6       Hyderabad  2017-04-05
# 2      1082592       2017               6            Pune  2017-04-06
# 3      1082593       2017               6          Rajkot  2017-04-07
# 4      1082594       2017               6          Indore  2017-04-08
# ...        ...        ...             ...             ...         ...
# 1207   1529282       2026               6           Delhi  2026-04-27
# 1208   1529283       2026               6  New Chandigarh  2026-04-28
# 1209   1529284       2026               6          Mumbai  2026-04-29
# 1210   1529285       2026               6       Ahmedabad  2026-04-30
# 1211   1529286       2026               6          Jaipur  2026-05-01
#
#                  event_name  match_number gender match_type format  ...  \
# ...

# %%
def run_sql_file(path):
    with open(path,'r') as f:
        script=f.read()
    con.executescript(script)
    con.commit()
    print('ran',path)

# %%
run_sql_file(r"C:\Users\msham\OneDrive\Documents\OJT\Proj3.1\Sql\Practice\01_nulls_and_blanks.sql")
# Out:
# ran C:\Users\msham\OneDrive\Documents\OJT\Proj3.1\Sql\Practice\01_nulls_and_blanks.sql

# %%
q("""SELECT COUNT(*) as blank_before
FROM players
WHERE TRIM(field_pos) = '';""")
# Out:
#    blank_before
# 0           612

# %%
q("""SELECT COUNT(*) AS null_after
FROM v_players_clean
WHERE field_pos_clean IS NULL;""")
# Out:
#    null_after
# 0         700

# %%
q("""SELECT DISTINCT team_name
FROM teams
ORDER BY team_name;"""
)
# Out:
#                       team_name
# 0           Chennai Super Kings
# 1               Deccan Chargers
# 2                Delhi Capitals
# 3                 Gujarat Lions
# 4                Gujarat Titans
# 5          Kochi Tuskers Kerala
# 6         Kolkata Knight Riders
# 7          Lucknow Super Giants
# 8                Mumbai Indians
# 9                 Pune Warriors
# 10                 Punjab Kings
# 11             Rajasthan Royals
# 12       Rising Pune Supergiant
# 13      Rising Pune Supergiants
# 14  Royal Challengers Bangalore
# 15          Sunrisers Hyderabad

# %%
q("""SELECT DISTINCT team_name_clean
FROM v_teams_clean
ORDER BY team_name_clean;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\OneDrive\Documents\OJT\Proj3.1\.venv\Lib\site-packages\pandas\io\sql.py:2745, in SQLiteDatabase.execute(self, sql, params)
#    2744 try:
# -> 2745     cur.execute(sql, *args)
#    2746     return cur
#
# OperationalError: no such table: v_teams_clean
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 q("""SELECT DISTINCT team_name_clean
#       2 FROM v_teams_clean
#       3 ORDER BY team_name_clean;""")
#
# Cell In[19], line 7, in q(sql)
#       6 def q(sql):
# ----> 7      return pd.read_sql(sql, con)
#
# ...
